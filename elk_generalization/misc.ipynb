# %%
import torch

torch.load("/workspace/elk-generalization/experiments/Mistral-7B-v0.1-authors/A/test/lm_log_odds.pt")
# Out:
# tensor([ 0.1250, -0.5000, -3.5000, -2.1250,  1.2500,  0.2500, -1.0000,  1.5000,
#          1.1250,  0.5000, -2.1250,  1.0000,  3.5000,  0.3750, -0.3750,  2.8750,
#          0.3750, -3.3750, -0.8750, -1.6250, -3.5000, -1.1250,  0.0000, -3.1250,
#          3.1250,  1.8750,  0.2500, -3.3750, -0.8750,  0.7500,  0.5000, -2.1250,
#         -0.1250,  1.6250, -2.1250, -0.8750,  2.5000,  2.0000, -1.7500,  1.5000,
#         -1.1250,  0.8750,  0.8750,  0.6250,  0.8750, -2.6250, -1.7500, -0.6250,
#          2.7500,  3.0000,  1.7500,  3.3750,  0.7500,  1.3750,  1.3750,  1.1250,
#          0.5000, -2.2500, -1.2500, -1.8750,  2.1250,  0.6250,  2.0000,  0.1250,
#         -0.3750, -2.6250, -2.0000,  1.1250,  0.3750,  0.8750,  2.8750, -0.3750,
#         -1.1250, -1.5000,  0.7500, -1.1250, -1.7500, -3.2500, -0.6250,  1.5000,
#          0.3750, -0.5000, -1.1250, -2.8750,  1.5000,  0.1250, -2.8750, -2.6250,
#         -3.1250, -0.6250,  2.6250, -0.8750,  3.1250,  1.0000,  0.2500,  0.8750,
# ...
